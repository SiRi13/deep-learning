# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

# %%
t = 1e-5
int_words_counter = Counter(int_words)
total = len(int_words)
word_freq_dict = {wrd: cnt / total for wrd, cnt in int_words_counter.items()}
drop_prop = {wrd: 1-np.sqrt(t/wrd_frq) for wrd, wrd_frq in word_freq_dict.items()}

# %%
## Your code here
train_words = [wrd for wrd in int_words if drop_prop[wrd] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    random_r = np.random.randint(1, window_size+1)
    low = idx-random_r if idx-random_r > 0 else 0
    high = idx+random_r
    return list(set(words[low:idx] + words[idx+1:high+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b, labels=labels, 
                                      inputs=embed, num_sampled=n_sampled, num_classes=n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6661 0.2382 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6186 0.2361 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4968 0.2216 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5754 0.2207 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5036 0.2169 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5351 0.2154 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5550 0.2204 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5597 0.2208 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4866 0.2277 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3990 0.2330 sec/batch
# Nearest to would: vistas, seebeck, safe, cossacks, aris, kilobit, eastwood, bramble,
# Nearest to system: crack, neil, rooming, scaled, unheated, nanotechnology, stops, subgroup,
# Nearest to seven: credited, suppositions, recognizing, voris, e, pedophiles, brazauskas, cruijff,
# Nearest to three: foxtrot, mushes, proprietor, smyrnaeans, normalcy, haji, ignorance, suffocation,
# Nearest to from: results, schismatic, completions, alcohols, shuja, confuses, spurious, lansing,
# Nearest to some: arbitration, spectacularly, durian, goes, inhaled, overseen, manitou, allotment,
# Nearest to united: controlling, originating, dimethyl, lx, vienne, mecha, itanium, liberties,
# Nearest to of: circumnavigate, insecure, ripley, tyndareus, lausanne, xxviii, elgin, conservative,
# Nearest to ocean: hugely, agnesi, utter, synthesised, guanine, asquith, ethnographers, adriatic,
# Nearest to frac: flirting, newcomen, leigh, miming, aladdin, enforced, amputee, mississippi,
# Nearest to square: werden, stewie, footnotes, comnenus, agn, rule, rediscovering, concacaf,
# Nearest to freedom: fuelling, loom, invoices, torquato, westphalia, quelques, hsi, quartile,
# Nearest to grand: bondage, regurgitated, lawlessness, resolute, prehistory, misinterpretation, nahum, astm,
# Nearest to heavy: privateers, brownies, muggles, hyacinth, fraudulent, gorges, availible, discontinued,
# Nearest to quite: insular, for, valueless, mbit, reason, gimps, engendered, pennsylvania,
# Nearest to hold: blocs, icosahedron, ernesto, dukakis, roofed, miskolc, apiece, namo,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4976 0.2424 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3859 0.2155 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3479 0.2185 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2416 0.2256 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2089 0.2134 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1555 0.2571 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0758 0.2233 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1023 0.2144 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9961 0.2252 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9754 0.2137 sec/batch
# Nearest to would: vistas, safe, perceived, cossacks, varied, rolling, seebeck, circle,
# Nearest to system: nanotechnology, stops, status, inches, their, crack, scaled, why,
# Nearest to seven: credited, e, suppositions, recognizing, five, arose, governs, half,
# Nearest to three: ii, smyrnaeans, comes, haji, ignorance, foxtrot, mushes, proprietor,
# Nearest to from: results, schismatic, spurious, said, lansing, alcohols, completions, shuja,
# Nearest to some: goes, will, apparently, arbitration, tendencies, esk, spectacularly, spontaneously,
# Nearest to united: controlling, originating, removed, takes, americas, programs, survives, everything,
# Nearest to of: circumnavigate, conservative, fewer, insecure, extinction, circular, are, verification,
# Nearest to ocean: hugely, utter, synthesised, guanine, outgrown, persisted, asquith, agnesi,
# Nearest to frac: flirting, leigh, newcomen, concept, enforced, mississippi, amputee, influenced,
# Nearest to square: werden, footnotes, rule, stewie, consecutive, runaway, answer, often,
# Nearest to freedom: fuelling, loom, quelques, torquato, invoices, road, westphalia, hellfire,
# Nearest to grand: regurgitated, prehistory, lawlessness, bondage, misinterpretation, future, dynamics, textbook,
# Nearest to heavy: brownies, privateers, gorges, tons, discontinued, twilight, hyacinth, chronic,
# Nearest to quite: for, reason, insular, pennsylvania, determines, tallest, brazil, mbit,
# Nearest to hold: blocs, icosahedron, billion, ernesto, lakeland, recombination, schuster, apiece,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9188 0.2205 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8956 0.2103 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8543 0.2098 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8646 0.2106 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8225 0.2108 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8458 0.2104 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7894 0.2108 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8118 0.2328 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7986 0.2292 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7881 0.2291 sec/batch
# Nearest to would: safe, vistas, seebeck, perceived, cossacks, pledge, conrad, hers,
# Nearest to system: nanotechnology, crack, subgroup, status, stops, neil, scaled, their,
# Nearest to seven: five, credited, presenter, recognizing, suppositions, hypermedia, arose, roth,
# Nearest to three: ii, foxtrot, smyrnaeans, cia, privy, ignorance, proprietor, mushes,
# Nearest to from: results, schismatic, confuses, conducts, lansing, completions, said, alcohols,
# Nearest to some: spectacularly, arbitration, tendencies, goes, overseen, spontaneously, acutely, forge,
# Nearest to united: controlling, americas, takes, originating, seized, liberties, deal, oren,
# Nearest to of: circumnavigate, lausanne, fewer, insecure, guilt, conservative, extinction, verification,
# Nearest to ocean: hugely, persisted, utter, consorts, synthesised, black, outgrown, guanine,
# Nearest to frac: flirting, leigh, papers, newcomen, stuffed, meritorious, scarcely, organizes,
# Nearest to square: werden, footnotes, runaway, rule, stewie, consecutive, fertility, answer,
# Nearest to freedom: fuelling, loom, westphalia, open, quelques, invoices, wilson, torquato,
# Nearest to grand: regurgitated, misinterpretation, bondage, lawlessness, prehistory, resolute, future, sucked,
# Nearest to heavy: privateers, brownies, gorges, tons, twilight, discontinued, analyst, fraudulent,
# Nearest to quite: insular, for, reason, mbit, determines, pennsylvania, tallest, cathedra,
# Nearest to hold: blocs, ernesto, icosahedron, billion, waterfall, recombination, namo, dukakis,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7987 0.2180 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7609 0.2118 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7164 0.2141 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6947 0.2113 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7409 0.2269 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6818 0.2308 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6942 0.2129 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7404 0.2127 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7307 0.2120 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6688 0.2208 sec/batch
# Nearest to would: safe, vistas, seebeck, hers, perceived, cossacks, pledge, eastwood,
# Nearest to system: subgroup, nanotechnology, crack, status, stops, putting, unheated, frankish,
# Nearest to seven: five, presenter, eight, six, roth, ncaa, johann, credited,
# Nearest to three: five, one, ii, foxtrot, haji, american, norton, smyrnaeans,
# Nearest to from: results, schismatic, confuses, completions, morton, conducts, lansing, mingling,
# Nearest to some: arbitration, spectacularly, tendencies, overseen, spontaneously, acutely, audiovisual, desired,
# Nearest to united: controlling, oren, americas, dimethyl, seized, deal, locusts, vanities,
# Nearest to of: lausanne, circumnavigate, guilt, plautus, fewer, ann, tyndareus, ta,
# Nearest to ocean: hugely, consorts, persisted, outgrown, ethers, asquith, utter, ethnographers,
# Nearest to frac: flirting, leigh, y, newcomen, stuffed, meritorious, scarcely, psyche,
# Nearest to square: werden, footnotes, stewie, runaway, agn, vitally, comnenus, rule,
# Nearest to freedom: fuelling, loom, westphalia, torquato, hellfire, invoices, quelques, johnny,
# Nearest to grand: bondage, misinterpretation, resolute, lawlessness, regurgitated, area, sucked, prehistory,
# Nearest to heavy: privateers, fraudulent, brownies, twilight, trieste, gorges, hardliners, analyst,
# Nearest to quite: insular, for, reason, mbit, determines, cathedra, engendered, onlookers,
# Nearest to hold: blocs, recombination, waterfall, trope, ernesto, namo, icosahedron, billion,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6462 0.2128 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6598 0.2099 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6449 0.2219 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6277 0.2232 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6288 0.2107 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6483 0.2100 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6109 0.1556 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5551 0.2108 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4980 0.2106 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5012 0.2114 sec/batch
# Nearest to would: safe, seebeck, vistas, eastwood, hers, perceived, cossacks, pledge,
# Nearest to system: nanotechnology, subgroup, status, crack, einem, stops, disks, telephones,
# Nearest to seven: five, presenter, six, eight, roth, johann, two, ncaa,
# Nearest to three: one, five, ii, american, norton, six, nine, foxtrot,
# Nearest to from: results, schismatic, confuses, completions, morton, mingling, said, candles,
# Nearest to some: arbitration, tendencies, acutely, spectacularly, allotment, spontaneously, desired, audiovisual,
# Nearest to united: controlling, oren, seized, dimethyl, filings, taraki, americas, vanities,
# Nearest to of: lausanne, ann, guilt, circumnavigate, fewer, sofie, plautus, mens,
# Nearest to ocean: hugely, consorts, ethnographers, antiderivatives, ethers, outgrown, asquith, legis,
# Nearest to frac: y, flirting, newcomen, leigh, stuffed, gras, liquid, meritorious,
# Nearest to square: werden, footnotes, runaway, agn, stewie, vitally, comnenus, rustic,
# Nearest to freedom: fuelling, loom, westphalia, torquato, invoices, hellfire, hsi, quartile,
# Nearest to grand: bondage, misinterpretation, resolute, area, lawlessness, sucked, ochs, prehistory,
# Nearest to heavy: privateers, fraudulent, brownies, trieste, hardliners, gorges, analyst, improvisation,
# Nearest to quite: insular, reason, for, mbit, determines, valueless, cathedra, onlookers,
# Nearest to hold: blocs, trope, waterfall, recombination, namo, roofed, seeps, apiece,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4917 0.2127 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5134 0.2104 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4417 0.2101 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5262 0.2093 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4895 0.2102 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4476 0.2097 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4560 0.2100 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4247 0.2104 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4228 0.2181 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4202 0.2094 sec/batch
# Nearest to would: safe, vistas, seebeck, hers, pledge, perceived, cite, put,
# Nearest to system: subgroup, disks, nanotechnology, einem, telephones, status, crack, stops,
# Nearest to seven: five, roth, presenter, six, eight, ncaa, johann, suppositions,
# Nearest to three: five, haji, one, total, smyrnaeans, og, ii, norton,
# Nearest to from: confuses, schismatic, results, completions, morton, spurious, candles, shuja,
# Nearest to some: arbitration, acutely, spectacularly, tendencies, allotment, spontaneously, clitic, inhaled,
# Nearest to united: oren, seized, controlling, redskins, americas, taraki, filings, liberties,
# Nearest to of: lausanne, circumnavigate, plautus, fewer, celestial, guilt, sum, emphasizing,
# Nearest to ocean: hugely, antiderivatives, consorts, adriatic, ethnographers, mountainous, black, ethers,
# Nearest to frac: y, flirting, t, g, liquid, newcomen, gras, length,
# Nearest to square: werden, footnotes, runaway, agn, stewie, electrified, transport, vitally,
# Nearest to freedom: fuelling, loom, invoices, hsi, torquato, hellfire, westphalia, quartile,
# Nearest to grand: bondage, misinterpretation, area, ochs, resolute, lawlessness, psychologist, sucked,
# Nearest to heavy: hardliners, privateers, fraudulent, improvisation, gorges, tons, exuberance, analyst,
# Nearest to quite: reason, insular, determines, for, mbit, valueless, cathedra, onlookers,
# Nearest to hold: blocs, trope, waterfall, roofed, recombination, seeps, dukakis, desecration,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4184 0.2125 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4048 0.2097 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4220 0.2098 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4113 0.2106 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4095 0.2096 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4302 0.2104 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3600 0.2159 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3995 0.2094 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4251 0.2103 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4045 0.2101 sec/batch
# Nearest to would: safe, seebeck, vistas, hers, put, pledge, ahistorical, perceived,
# Nearest to system: subgroup, telephones, disks, status, nanotechnology, einem, stops, crack,
# Nearest to seven: five, six, eight, presenter, roth, ncaa, shel, two,
# Nearest to three: one, five, haji, six, total, norton, smyrnaeans, nine,
# Nearest to from: confuses, results, schismatic, completions, selves, candles, animate, lansing,
# Nearest to some: arbitration, acutely, tendencies, spectacularly, clitic, conclusions, allotment, constitutes,
# Nearest to united: oren, seized, filings, americas, redskins, liberties, taraki, controlling,
# Nearest to of: lausanne, sofie, guilt, plautus, xxviii, circumnavigate, watchdog, tyndareus,
# Nearest to ocean: hugely, antiderivatives, mountainous, subtropical, adriatic, consorts, northwest, kilometers,
# Nearest to frac: y, t, g, delta, mathbf, sum, flirting, length,
# Nearest to square: werden, runaway, footnotes, stewie, agn, electrified, flame, photonic,
# Nearest to freedom: fuelling, loom, invoices, hsi, hellfire, westphalia, southside, torquato,
# Nearest to grand: bondage, misinterpretation, ochs, resolute, area, psychologist, usta, sucked,
# Nearest to heavy: tons, privateers, hardliners, gorges, improvisation, exuberance, fraudulent, twilight,
# Nearest to quite: reason, insular, determines, mbit, for, unwanted, cathedra, linens,
# Nearest to hold: blocs, trope, recombination, roofed, waterfall, narmer, maintain, belfry,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4013 0.2122 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4020 0.2107 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3661 0.2104 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3723 0.2099 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3898 0.2097 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3758 0.2110 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4008 0.2102 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3921 0.2099 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3650 0.2098 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3510 0.2096 sec/batch
# Nearest to would: safe, vistas, hers, put, seebeck, threatened, memnon, pledge,
# Nearest to system: telephones, disks, status, subgroup, einem, nanotechnology, basis, coronets,
# Nearest to seven: five, eight, six, two, roth, e, presenter, one,
# Nearest to three: five, one, total, six, haji, four, nine, est,
# Nearest to from: confuses, schismatic, results, selves, completions, candles, spurious, goatskin,
# Nearest to some: arbitration, acutely, shri, spectacularly, clitic, persisting, promoting, conclusions,
# Nearest to united: oren, liberties, filings, union, americas, seized, taraki, redskins,
# Nearest to of: lausanne, greek, cyprus, watchdog, plautus, ta, ra, constituent,
# Nearest to ocean: adriatic, mountainous, subtropical, antiderivatives, hugely, pacific, northwest, kilometers,
# Nearest to frac: y, t, g, delta, rightarrow, sum, mathbf, newcomen,
# Nearest to square: werden, runaway, footnotes, stewie, electrified, agn, photonic, transport,
# Nearest to freedom: fuelling, loom, hsi, invoices, hellfire, westphalia, quartile, persuasive,
# Nearest to grand: bondage, misinterpretation, resolute, ochs, area, lawlessness, sucked, prehistory,
# Nearest to heavy: tons, hardliners, privateers, twilight, gorges, exuberance, availible, improvisation,
# Nearest to quite: reason, insular, valueless, determines, mbit, cathedra, for, linens,
# Nearest to hold: blocs, trope, roofed, recombination, narmer, maintain, waterfall, desecration,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3182 0.2166 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2951 0.2132 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3609 0.2112 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3696 0.2103 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3744 0.2096 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3090 0.2099 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2889 0.2097 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3356 0.2097 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2065 0.2104 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3075 0.2104 sec/batch
# Nearest to would: safe, seebeck, put, hers, vistas, threatened, memnon, knees,
# Nearest to system: telephones, disks, status, subgroup, einem, broadcast, cellular, nanotechnology,
# Nearest to seven: five, eight, six, two, one, zero, lauper, roth,
# Nearest to three: one, five, six, total, nine, four, zero, haji,
# Nearest to from: confuses, results, selves, schismatic, goatskin, completions, mingling, lansing,
# Nearest to some: arbitration, acutely, noun, shri, clitic, persisting, spectacularly, tendencies,
# Nearest to united: oren, liberties, filings, taraki, union, sizable, agencies, seized,
# Nearest to of: lausanne, ta, cyprus, celestial, pasha, abbeys, greek, emphasizing,
# Nearest to ocean: adriatic, subtropical, mountainous, antiderivatives, hugely, northwest, pacific, consorts,
# Nearest to frac: y, delta, t, mathbf, rightarrow, g, sum, mascheroni,
# Nearest to square: werden, footnotes, runaway, stewie, electrified, agn, photonic, visitor,
# Nearest to freedom: fuelling, loom, hsi, invoices, quartile, torquato, hellfire, westphalia,
# Nearest to grand: bondage, area, ochs, resolute, usta, misinterpretation, transitional, lawlessness,
# Nearest to heavy: tons, privateers, hardliners, improvisation, gorges, exuberance, twilight, trieste,
# Nearest to quite: reason, insular, valueless, mbit, linens, cathedra, interrelated, determines,
# Nearest to hold: blocs, roofed, trope, maintain, narmer, recombination, participatory, waterfall,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3149 0.2127 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3416 0.2110 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3249 0.1011 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2271 0.2095 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2167 0.2107 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2194 0.2112 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2025 0.2110 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2057 0.2105 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2450 0.2101 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1733 0.2098 sec/batch
# Nearest to would: safe, put, seebeck, vistas, hers, knees, pledge, threatened,
# Nearest to system: telephones, disks, status, broadcast, macs, subgroup, ytv, cellular,
# Nearest to seven: five, eight, two, six, one, zero, e, roth,
# Nearest to three: five, one, six, total, four, two, nine, haji,
# Nearest to from: confuses, results, goatskin, selves, completions, schismatic, sinking, mingling,
# Nearest to some: arbitration, acutely, clitic, allotment, encourages, noun, spectacularly, moustache,
# Nearest to united: filings, oren, liberties, agencies, taraki, controlling, enso, public,
# Nearest to of: lausanne, celestial, ann, ta, age, cyprus, and, greek,
# Nearest to ocean: adriatic, subtropical, hugely, mountainous, antiderivatives, persisted, consorts, pacific,
# Nearest to frac: y, delta, mathbf, t, sum, mascheroni, g, rightarrow,
# Nearest to square: werden, stewie, agn, footnotes, electrified, runaway, visitor, photonic,
# Nearest to freedom: fuelling, hsi, invoices, loom, quartile, torquato, hellfire, desargues,
# Nearest to grand: bondage, resolute, area, misinterpretation, sucked, usta, lawlessness, ochs,
# Nearest to heavy: tons, gorges, rear, exuberance, privateers, improvisation, twilight, hardliners,
# Nearest to quite: insular, reason, valueless, interrelated, mbit, determines, linens, fsf,
# Nearest to hold: blocs, trope, roofed, participatory, maintain, recombination, narmer, waterfall,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2470 0.2132 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2275 0.2095 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2162 0.2098 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1002 0.2109 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1507 0.2102 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1409 0.2097 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1442 0.2095 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1986 0.2097 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1989 0.2106 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1792 0.2097 sec/batch
# Nearest to would: safe, put, seebeck, vistas, hers, pledge, threatened, knees,
# Nearest to system: telephones, disks, status, ytv, subgroup, tweaked, mosul, ofcom,
# Nearest to seven: five, eight, two, six, zero, one, e, ly,
# Nearest to three: five, one, total, six, four, two, rate, zero,
# Nearest to from: confuses, results, schismatic, goatskin, selves, hesitated, animate, inactivation,
# Nearest to some: arbitration, acutely, encourages, clitic, noun, allotment, charset, tendencies,
# Nearest to united: filings, oren, liberties, agencies, civil, enso, americas, taraki,
# Nearest to of: celestial, lausanne, age, for, constituent, dtft, and, plautus,
# Nearest to ocean: adriatic, hugely, subtropical, persisted, mountainous, antiderivatives, consorts, northwest,
# Nearest to frac: delta, y, mathbf, t, mascheroni, rightarrow, sqrt, sum,
# Nearest to square: werden, stewie, photonic, agn, electrified, runaway, visitor, olmsted,
# Nearest to freedom: fuelling, loom, hsi, invoices, quartile, persuasive, desargues, hellfire,
# Nearest to grand: bondage, resolute, usta, sucked, area, lawlessness, transitional, misinterpretation,
# Nearest to heavy: tons, rear, gorges, hardliners, privateers, exuberance, improvisation, twilight,
# Nearest to quite: reason, insular, valueless, interrelated, linens, mbit, cathedra, fsf,
# Nearest to hold: blocs, trope, participatory, roofed, recombination, maintain, began, narmer,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1735 0.2117 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2271 0.2107 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1575 0.2115 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1669 0.2092 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1894 0.2097 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1733 0.2097 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2123 0.2104 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1826 0.2096 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1574 0.2104 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1670 0.2098 sec/batch
# Nearest to would: put, safe, pledge, hers, knees, threatened, perceived, memnon,
# Nearest to system: telephones, status, ytv, subgroup, mosul, disks, tweaked, in,
# Nearest to seven: five, eight, two, six, zero, one, e, brazauskas,
# Nearest to three: five, one, six, total, four, two, zero, nine,
# Nearest to from: results, selves, goatskin, confuses, schismatic, knotted, animate, mingling,
# Nearest to some: arbitration, acutely, tendencies, moustache, encourages, charset, persisting, shunned,
# Nearest to united: filings, liberties, oren, states, americas, agencies, junius, enso,
# Nearest to of: lausanne, travail, cyprus, for, and, celestial, at, age,
# Nearest to ocean: adriatic, subtropical, hugely, persisted, antiderivatives, mountainous, assab, pacific,
# Nearest to frac: delta, mathbf, mascheroni, t, y, rightarrow, sum, sqrt,
# Nearest to square: werden, photonic, stewie, runaway, electrified, euclidean, visitor, olmsted,
# Nearest to freedom: fuelling, loom, hsi, invoices, quartile, persuasive, hellfire, desargues,
# Nearest to grand: bondage, usta, sucked, resolute, sailboat, transitional, lawlessness, misinterpretation,
# Nearest to heavy: tons, gorges, rear, exuberance, hardliners, arms, privateers, improvisation,
# Nearest to quite: reason, insular, valueless, interrelated, linens, mbit, fsf, determines,
# Nearest to hold: blocs, participatory, trope, roofed, recombination, narmer, maintain, inwards,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2404 0.2130 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1717 0.2115 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1620 0.2102 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1913 0.2103 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1432 0.2108 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1779 0.2096 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1741 0.2105 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1192 0.2115 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2110 0.2113 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2085 0.2112 sec/batch
# Nearest to would: put, safe, hers, pledge, threatened, memnon, rearmament, passionately,
# Nearest to system: telephones, status, ytv, mosul, cellular, subgroup, basis, disks,
# Nearest to seven: five, eight, two, six, zero, one, nine, three,
# Nearest to three: five, one, six, four, two, nine, zero, total,
# Nearest to from: results, selves, goatskin, schismatic, authorities, mingling, lusignan, normans,
# Nearest to some: arbitration, acutely, tendencies, moustache, noun, shri, apparently, animist,
# Nearest to united: filings, liberties, states, oren, agencies, civil, joplin, new,
# Nearest to of: lausanne, for, travail, and, age, former, sofie, archbishop,
# Nearest to ocean: adriatic, subtropical, hugely, persisted, assab, pacific, consorts, antiderivatives,
# Nearest to frac: delta, mascheroni, mathbf, y, t, sum, rightarrow, ldots,
# Nearest to square: werden, photonic, stewie, visitor, agn, footnotes, electrified, cbe,
# Nearest to freedom: fuelling, loom, quartile, hsi, invoices, racists, persuasive, desargues,
# Nearest to grand: usta, sailboat, resolute, bondage, sucked, misinterpretation, lawlessness, admirals,
# Nearest to heavy: tons, rear, improvisation, exuberance, privateers, gorges, wwii, arms,
# Nearest to quite: reason, insular, valueless, interrelated, linens, fsf, mbit, datasets,
# Nearest to hold: blocs, participatory, trope, roofed, recombination, began, maintain, narmer,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2501 0.2126 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1337 0.2111 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1432 0.2089 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1602 0.2092 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0407 0.2109 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1608 0.2113 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1763 0.2099 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1167 0.2111 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1816 0.0467 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1017 0.2104 sec/batch
# Nearest to would: put, safe, hers, memnon, seebeck, pledge, knees, rearmament,
# Nearest to system: telephones, disks, ytv, in, status, cellular, multitasking, mosul,
# Nearest to seven: five, eight, two, six, zero, one, nine, three,
# Nearest to three: five, one, six, four, two, zero, total, nine,
# Nearest to from: results, goatskin, authorities, selves, mingling, knotted, spoleto, confuses,
# Nearest to some: arbitration, acutely, apparently, bedouin, moustache, persisting, arabism, allotment,
# Nearest to united: filings, states, liberties, oren, agencies, joplin, americas, ottawa,
# Nearest to of: and, lausanne, for, age, celestial, in, cyprus, fewer,
# Nearest to ocean: adriatic, subtropical, hugely, persisted, assab, andaman, antiderivatives, pacific,
# Nearest to frac: delta, mascheroni, t, mathbf, newcomen, y, length, flirting,
# Nearest to square: werden, stewie, photonic, visitor, euclidean, olmsted, cbe, agn,
# Nearest to freedom: fuelling, loom, quartile, hsi, invoices, racists, desargues, persuasive,
# Nearest to grand: usta, sailboat, lawlessness, resolute, sucked, transitional, area, hann,
# Nearest to heavy: tons, rear, improvisation, exuberance, privateers, gorges, arms, wwii,
# Nearest to quite: reason, insular, valueless, interrelated, linens, fsf, datasets, recognizing,
# Nearest to hold: blocs, participatory, trope, began, roofed, ventured, maintain, narmer,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0839 0.2136 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0707 0.2109 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0750 0.2103 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0289 0.2103 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0784 0.2105 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0546 0.2105 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0941 0.2106 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0885 0.2097 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1164 0.2106 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0181 0.2105 sec/batch
# Nearest to would: put, safe, knees, pledge, memnon, hers, record, threatened,
# Nearest to system: telephones, disks, status, ytv, cellular, mosul, ofcom, in,
# Nearest to seven: five, eight, two, six, zero, one, three, nine,
# Nearest to three: five, one, six, four, two, zero, total, nine,
# Nearest to from: results, goatskin, selves, mingling, confuses, authorities, bitola, lusignan,
# Nearest to some: arbitration, allotment, acutely, clitic, apparently, encourages, arabism, moustache,
# Nearest to united: filings, states, liberties, oren, agencies, licences, joplin, americas,
# Nearest to of: and, for, lausanne, in, age, celestial, cyprus, teixeira,
# Nearest to ocean: adriatic, subtropical, hugely, persisted, pacific, andaman, assab, intersputnik,
# Nearest to frac: delta, mascheroni, t, mathbf, length, sqrt, newcomen, y,
# Nearest to square: werden, stewie, visitor, photonic, malden, cbe, euclidean, agn,
# Nearest to freedom: fuelling, loom, quartile, invoices, hsi, persuasive, racists, desargues,
# Nearest to grand: usta, sailboat, sucked, duchy, lawlessness, misinterpretation, admirals, resolute,
# Nearest to heavy: tons, rear, improvisation, exuberance, arms, privateers, wwii, clerical,
# Nearest to quite: reason, insular, interrelated, valueless, linens, loyalties, tainted, recognizing,
# Nearest to hold: blocs, participatory, roofed, trope, belfry, began, ventured, cheesy,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0240 0.2125 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0712 0.2107 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0097 0.2090 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0653 0.2093 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0931 0.2110 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0882 0.2103 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.1048 0.2102 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1032 0.2107 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0231 0.2107 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0522 0.2096 sec/batch
# Nearest to would: put, safe, knees, memnon, pledge, record, passionately, hers,
# Nearest to system: telephones, ytv, cellular, mosul, status, ofcom, in, basis,
# Nearest to seven: five, eight, two, six, zero, one, nine, three,
# Nearest to three: five, one, six, four, two, zero, nine, total,
# Nearest to from: results, goatskin, authorities, selves, mingling, of, lusignan, schismatic,
# Nearest to some: acutely, arbitration, apparently, allotment, encourages, moustache, arabism, charset,
# Nearest to united: filings, states, liberties, oren, americas, joplin, licences, agencies,
# Nearest to of: and, for, in, is, age, two, disclaimers, constituent,
# Nearest to ocean: adriatic, subtropical, hugely, persisted, pacific, assab, andaman, intersputnik,
# Nearest to frac: delta, mascheroni, t, mathbf, omega, y, rightarrow, equiv,
# Nearest to square: werden, photonic, stewie, euclidean, visitor, cofinal, disjoint, cbe,
# Nearest to freedom: fuelling, loom, quartile, invoices, racists, persuasive, desargues, mores,
# Nearest to grand: sailboat, usta, sucked, admirals, hann, duchy, misinterpretation, lawlessness,
# Nearest to heavy: tons, improvisation, rear, privateers, exuberance, wwii, clerical, gorges,
# Nearest to quite: reason, insular, interrelated, valueless, linens, loyalties, datasets, tainted,
# Nearest to hold: blocs, participatory, trope, roofed, cheesy, ventured, acrylics, recombination,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0748 0.2128 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0674 0.2105 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0690 0.2113 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0711 0.2092 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0582 0.2109 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0695 0.2108 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0823 0.2096 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0568 0.2109 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0727 0.2099 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0319 0.2107 sec/batch
# Nearest to would: put, memnon, safe, pledge, hers, record, knees, passionately,
# Nearest to system: telephones, cellular, ytv, disks, ofcom, mosul, status, multitasking,
# Nearest to seven: five, eight, two, six, zero, one, three, four,
# Nearest to three: five, one, six, four, two, zero, nine, total,
# Nearest to from: of, goatskin, results, selves, authorities, lusignan, mingling, spurious,
# Nearest to some: moustache, apparently, acutely, arbitration, shri, arabism, guild, charset,
# Nearest to united: states, filings, liberties, oren, licences, americas, joplin, agencies,
# Nearest to of: and, in, the, lausanne, archbishop, from, for, two,
# Nearest to ocean: adriatic, hugely, pacific, subtropical, persisted, assab, intersputnik, andaman,
# Nearest to frac: delta, mascheroni, t, omega, mathbf, equiv, rightarrow, sqrt,
# Nearest to square: werden, photonic, stewie, visitor, euclidean, cbe, rustic, olmsted,
# Nearest to freedom: fuelling, loom, quartile, invoices, persuasive, racists, desargues, gratis,
# Nearest to grand: sailboat, usta, duchy, admirals, sucked, misinterpretation, remanded, archdukes,
# Nearest to heavy: improvisation, exuberance, clerical, tons, wwii, rear, privateers, twilight,
# Nearest to quite: reason, insular, interrelated, datasets, valueless, linens, msh, loyalties,
# Nearest to hold: blocs, participatory, trope, belfry, acrylics, content, cheesy, recombination,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0796 0.2123 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0138 0.2101 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0569 0.2100 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0573 0.2113 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0616 0.2128 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1187 0.2101 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1420 0.2098 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0812 0.2103 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0339 0.2090 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0465 0.2093 sec/batch
# Nearest to would: put, safe, memnon, pledge, record, hers, stationery, knees,
# Nearest to system: telephones, ytv, cellular, disks, mosul, basis, ofcom, multitasking,
# Nearest to seven: five, eight, two, six, zero, one, three, four,
# Nearest to three: five, one, six, four, two, zero, nine, total,
# Nearest to from: results, of, authorities, selves, goatskin, mingling, lusignan, spurious,
# Nearest to some: apparently, allotment, arabism, moustache, acutely, clitic, arbitration, archontology,
# Nearest to united: states, filings, liberties, oren, civil, agencies, licences, obtain,
# Nearest to of: and, in, for, from, the, teixeira, at, lausanne,
# Nearest to ocean: adriatic, hugely, intersputnik, pacific, persisted, andaman, subtropical, assab,
# Nearest to frac: delta, mascheroni, t, approximates, equiv, mathbf, omega, sqrt,
# Nearest to square: werden, photonic, stewie, euclidean, visitor, cbe, olmsted, cofinal,
# Nearest to freedom: fuelling, loom, quartile, racists, desargues, invoices, persuasive, open,
# Nearest to grand: usta, duchy, admirals, sailboat, misinterpretation, archdukes, sucked, remanded,
# Nearest to heavy: improvisation, exuberance, clerical, tons, privateers, wwii, rear, harley,
# Nearest to quite: reason, interrelated, insular, valueless, for, msh, datasets, loyalties,
# Nearest to hold: blocs, participatory, trope, content, cheesy, acrylics, recombination, began,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9847 0.2133 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0158 0.2102 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0333 0.2109 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0365 0.2103 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0641 0.2098 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0487 0.2082 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9859 0.2103 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9788 0.2111 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0090 0.2104 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9754 0.2103 sec/batch
# Nearest to would: put, safe, pledge, memnon, record, hers, knees, stationery,
# Nearest to system: telephones, disks, ytv, multitasking, cellular, neil, tinymush, macs,
# Nearest to seven: five, eight, two, six, zero, one, three, four,
# Nearest to three: five, one, six, four, two, zero, nine, eight,
# Nearest to from: results, of, authorities, lusignan, goatskin, selves, radiotelephone, mingling,
# Nearest to some: allotment, apparently, arabism, ascribe, acutely, moustache, arbitration, encourages,
# Nearest to united: states, filings, liberties, oren, joplin, makah, cree, ilo,
# Nearest to of: and, in, the, at, for, from, teixeira, lausanne,
# Nearest to ocean: adriatic, andaman, pacific, hugely, persisted, intersputnik, subtropical, extensive,
# Nearest to frac: delta, mascheroni, t, approximates, equiv, omega, sqrt, mathbf,
# Nearest to square: werden, photonic, stewie, barely, visitor, houses, euclidean, cbe,
# Nearest to freedom: fuelling, quartile, loom, invoices, desargues, racists, gratis, servile,
# Nearest to grand: sailboat, usta, duchy, admirals, misinterpretation, archdukes, sucked, petrie,
# Nearest to heavy: improvisation, exuberance, clerical, tons, wwii, privateers, rear, harley,
# Nearest to quite: reason, insular, interrelated, for, valueless, datasets, loyalties, linens,
# Nearest to hold: blocs, participatory, trope, acrylics, began, covenants, belfry, content,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9830 0.2128 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9321 0.2127 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0005 0.2376 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0135 0.2350 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0239 0.2115 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0081 0.2112 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8905 0.2101 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9518 0.2096 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9400 0.2093 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0036 0.2096 sec/batch
# Nearest to would: put, memnon, pledge, safe, record, knees, hers, alexandrians,
# Nearest to system: telephones, cellular, ytv, disks, mosul, neil, status, multitasking,
# Nearest to seven: five, eight, two, six, zero, one, three, four,
# Nearest to three: five, one, six, two, four, zero, nine, eight,
# Nearest to from: results, of, authorities, goatskin, spurious, cinder, mingling, unenforceable,
# Nearest to some: allotment, apparently, insides, ascribe, arabism, moustache, non, acutely,
# Nearest to united: states, filings, liberties, america, oren, americas, licences, cree,
# Nearest to of: and, for, the, in, at, a, two, from,
# Nearest to ocean: adriatic, pacific, hugely, andaman, intersputnik, persisted, subtropical, assab,
# Nearest to frac: delta, mascheroni, t, approximates, omega, equiv, sqrt, mathbf,
# Nearest to square: werden, photonic, stewie, houses, barely, olmsted, disjoint, euclidean,
# Nearest to freedom: fuelling, quartile, loom, desargues, gratis, invoices, racists, racism,
# Nearest to grand: usta, sailboat, duchy, admirals, sucked, misinterpretation, archdukes, doubles,
# Nearest to heavy: improvisation, clerical, exuberance, tons, wwii, rear, harley, ironworks,
# Nearest to quite: reason, insular, interrelated, msh, for, datasets, valueless, loyalties,
# Nearest to hold: blocs, participatory, began, covenants, content, belfry, trope, acrylics,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9764 0.2127 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9592 0.2092 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9841 0.2105 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0120 0.2098 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0339 0.2100 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9595 0.2105 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9846 0.2104 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0074 0.2098 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0003 0.2127 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0035 0.2102 sec/batch
# Nearest to would: put, memnon, record, pledge, safe, hers, alexandrians, knees,
# Nearest to system: telephones, ytv, cellular, disks, mosul, basis, status, multitasking,
# Nearest to seven: five, eight, six, two, zero, one, three, nine,
# Nearest to three: one, five, six, four, two, zero, nine, eight,
# Nearest to from: of, results, authorities, selves, philosophically, lusignan, goatskin, mingling,
# Nearest to some: moustache, allotment, apparently, non, ascribe, arabism, acutely, monist,
# Nearest to united: states, filings, liberties, america, americas, joplin, makah, oren,
# Nearest to of: and, for, in, the, at, a, is, from,
# Nearest to ocean: adriatic, pacific, hugely, andaman, intersputnik, subtropical, assab, persisted,
# Nearest to frac: delta, mascheroni, approximates, t, mathbf, omega, equiv, bentheim,
# Nearest to square: werden, photonic, stewie, houses, barely, olmsted, serpent, cbe,
# Nearest to freedom: fuelling, quartile, loom, desargues, invoices, gratis, racists, constitutionalism,
# Nearest to grand: sailboat, usta, admirals, duchy, sucked, misinterpretation, petrie, doubles,
# Nearest to heavy: improvisation, clerical, exuberance, tons, wwii, rear, privateers, steaming,
# Nearest to quite: reason, insular, datasets, interrelated, msh, for, linens, valueless,
# Nearest to hold: blocs, participatory, covenants, content, trope, belfry, began, recombination,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0094 0.2136 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9698 0.2107 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9643 0.2099 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0001 0.2102 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0018 0.2105 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0078 0.2102 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9773 0.2116 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9638 0.2113 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9714 0.2115 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0178 0.2141 sec/batch
# Nearest to would: put, memnon, record, pledge, stationery, safe, salian, hers,
# Nearest to system: telephones, cellular, ytv, status, disks, basis, mosul, tinymush,
# Nearest to seven: five, eight, two, six, zero, one, three, nine,
# Nearest to three: five, one, four, six, two, zero, eight, nine,
# Nearest to from: of, results, authorities, mingling, goatskin, philosophically, lusignan, by,
# Nearest to some: non, ascribe, allotment, arabism, apparently, charset, even, moustache,
# Nearest to united: states, filings, liberties, makah, america, ilo, americas, civil,
# Nearest to of: and, in, the, for, from, at, a, two,
# Nearest to ocean: adriatic, pacific, hugely, andaman, intersputnik, persisted, atlantic, assab,
# Nearest to frac: delta, mascheroni, t, approximates, equiv, mathbf, omega, newcomen,
# Nearest to square: werden, photonic, stewie, often, olmsted, cbe, barely, disjoint,
# Nearest to freedom: fuelling, loom, quartile, desargues, guant, invoices, racists, etymologies,
# Nearest to grand: sailboat, admirals, usta, duchy, remanded, sucked, doubles, misinterpretation,
# Nearest to heavy: improvisation, clerical, exuberance, tons, steaming, wwii, harley, privateers,
# Nearest to quite: reason, insular, interrelated, msh, datasets, for, linens, loyalties,
# Nearest to hold: blocs, content, participatory, covenants, trope, acrylics, perpetuation, recombination,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9919 0.2142 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0848 0.2112 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0586 0.2105 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 3.9915 0.2099 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9729 0.2100 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9426 0.2095 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9712 0.2102 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9276 0.2105 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9581 0.2108 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9627 0.2099 sec/batch
# Nearest to would: put, memnon, record, stationery, hers, safe, pledge, utc,
# Nearest to system: telephones, cellular, ytv, disks, status, tweaked, in, mosul,
# Nearest to seven: five, eight, two, six, zero, one, three, nine,
# Nearest to three: one, five, six, four, two, zero, eight, nine,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8250 0.2098 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8457 0.2106 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8730 0.2098 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8901 0.2102 sec/batch
# Nearest to would: put, record, memnon, stationery, was, only, they, be,
# Nearest to system: telephones, cellular, systems, ytv, maha, body, tablet, soundex,
# Nearest to seven: five, eight, two, six, three, one, zero, four,
# Nearest to three: two, four, one, five, six, zero, eight, nine,
# Nearest to from: of, the, and, to, in, by, for, at,
# Nearest to some: such, are, ascribe, most, allotment, non, more, from,
# Nearest to united: states, america, makah, new, filings, york, kingdom, meanings,
# Nearest to of: and, the, in, is, for, a, from, which,
# Nearest to ocean: pacific, intersputnik, hugely, andaman, atlantic, incomes, berkley, tropospheric,
# Nearest to frac: mascheroni, delta, approximates, t, therefore, fraca, indication, permittivity,
# Nearest to square: photonic, werden, often, houses, marshlands, risc, stewie, serpent,
# Nearest to freedom: fuelling, quartile, constitutionalism, gratis, speech, stilwell, invoices, catholicism,
# Nearest to grand: admirals, usta, analgesic, misinterpretation, sailboat, doubles, duchy, hann,
# Nearest to heavy: improvisation, naught, metal, ironworks, exuberance, steaming, praenomen, reactor,
# Nearest to quite: reason, actually, msh, around, interrelated, for, datasets, explain,
# Nearest to hold: content, participatory, same, began, trope, covenants, sought, rotunda,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8384 0.2138 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8613 0.2102 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8555 0.2097 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8304 0.2115 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8635 0.2094 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8963 0.2108 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8477 0.2107 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8662 0.2100 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8764 0.2105 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8754 0.2112 sec/batch
# Nearest to would: put, record, memnon, stationery, salian, hoped, was, alexandrians,
# Nearest to system: telephones, cellular, systems, ytv, maha, body, soundex, mosul,
# Nearest to seven: five, eight, two, six, zero, one, three, four,
# Nearest to three: four, two, five, one, six, zero, eight, nine,
# Nearest to from: of, the, in, for, and, by, some, to,
# Nearest to some: such, most, are, ascribe, also, non, as, and,
# Nearest to united: states, america, makah, new, kingdom, filings, york, liberties,
# Nearest to of: and, the, in, is, which, for, from, by,
# Nearest to ocean: pacific, intersputnik, hugely, atlantic, andaman, tropospheric, berkley, incomes,
# Nearest to frac: mascheroni, delta, t, approximates, therefore, fraca, indication, cancels,
# Nearest to square: photonic, werden, often, marshlands, houses, risc, serpent, stewie,
# Nearest to freedom: fuelling, quartile, constitutionalism, gratis, speech, newsforge, recipients, stilwell,
# Nearest to grand: admirals, usta, analgesic, misinterpretation, sailboat, doubles, duchy, offence,
# Nearest to heavy: improvisation, metal, naught, ironworks, exuberance, steaming, reactor, plowed,
# Nearest to quite: reason, actually, msh, around, explain, interrelated, for, datasets,
# Nearest to hold: participatory, content, same, sought, began, trope, attempting, mansfeld,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8402 0.2135 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8377 0.2103 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8609 0.2104 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8629 0.2094 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9022 0.2115 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8469 0.2123 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9647 0.2105 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8978 0.2106 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8993 0.2104 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8188 0.2108 sec/batch
# Nearest to would: put, record, stationery, memnon, only, that, they, promised,
# Nearest to system: cellular, telephones, body, systems, ytv, maha, soundex, kabbalists,
# Nearest to seven: five, eight, two, zero, six, three, one, four,
# Nearest to three: two, four, five, one, six, zero, eight, nine,
# Nearest to from: of, the, for, in, and, by, to, on,
# Nearest to some: such, are, ascribe, also, non, the, most, from,
# Nearest to united: states, york, new, makah, america, filings, state, liberties,
# Nearest to of: and, the, in, is, for, from, which, by,
# Nearest to ocean: pacific, intersputnik, hugely, atlantic, andaman, berkley, incomes, tropospheric,
# Nearest to frac: mascheroni, delta, approximates, t, fraca, therefore, indication, schism,
# Nearest to square: photonic, werden, houses, often, marshlands, risc, mosul, stewie,
# Nearest to freedom: fuelling, quartile, constitutionalism, speech, gratis, recipients, stilwell, newsforge,
# Nearest to grand: usta, admirals, misinterpretation, duchy, analgesic, doubles, sailboat, offence,
# Nearest to heavy: metal, improvisation, exuberance, naught, steaming, ironworks, hedeby, reactor,
# Nearest to quite: reason, actually, msh, around, can, explain, isolated, interrelated,
# Nearest to hold: participatory, same, content, began, attempting, dented, regard, trope,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7984 0.2128 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8341 0.2094 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8063 0.2105 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8516 0.2111 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8554 0.2102 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8647 0.2101 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8748 0.1395 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8522 0.2112 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7961 0.2111 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8627 0.2113 sec/batch
# Nearest to would: put, memnon, was, they, record, only, not, stationery,
# Nearest to system: telephones, cellular, systems, ytv, body, staffers, maha, soundex,
# Nearest to seven: five, two, eight, six, zero, one, three, four,
# Nearest to three: two, four, one, five, six, eight, zero, seven,
# Nearest to from: of, the, in, and, for, by, to, on,
# Nearest to some: such, most, are, and, ascribe, the, also, from,
# Nearest to united: states, america, makah, new, york, filings, meanings, kingdom,
# Nearest to of: and, the, in, is, from, which, for, by,
# Nearest to ocean: pacific, intersputnik, hugely, atlantic, tropospheric, berkley, incomes, andaman,
# Nearest to frac: mascheroni, delta, approximates, t, fraca, therefore, indication, buber,
# Nearest to square: photonic, werden, marshlands, houses, often, risc, stewie, serpent,
# Nearest to freedom: fuelling, quartile, constitutionalism, recipients, speech, gratis, stilwell, invoices,
# Nearest to grand: usta, duchy, admirals, doubles, misinterpretation, sailboat, analgesic, justine,
# Nearest to heavy: metal, improvisation, ironworks, exuberance, steaming, naught, reactor, praenomen,
# Nearest to quite: reason, actually, around, msh, explain, isolated, interrelated, for,
# Nearest to hold: participatory, same, content, attempting, began, dented, trope, acrylics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8035 0.2130 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8134 0.2110 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8100 0.2109 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8574 0.2100 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8799 0.2109 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8203 0.2098 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8768 0.2104 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7140 0.2107 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8278 0.2112 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7908 0.2106 sec/batch
# Nearest to would: put, that, to, record, was, be, not, only,
# Nearest to system: telephones, cellular, systems, ytv, body, staffers, maha, largest,
# Nearest to seven: eight, five, two, six, zero, three, one, four,
# Nearest to three: two, four, one, five, six, eight, zero, seven,
# Nearest to from: of, the, in, and, for, to, on, some,
# Nearest to some: such, most, are, the, and, also, from, as,
# Nearest to united: states, america, new, makah, kingdom, meanings, york, filings,
# Nearest to of: and, the, in, for, is, which, a, to,
# Nearest to ocean: pacific, intersputnik, hugely, berkley, atlantic, incomes, tropospheric, andaman,
# Nearest to frac: mascheroni, delta, approximates, t, fraca, therefore, indication, buber,
# Nearest to square: photonic, houses, werden, marshlands, risc, often, stewie, genuinely,
# Nearest to freedom: fuelling, quartile, constitutionalism, speech, recipients, gratis, stilwell, invoices,
# Nearest to grand: usta, admirals, duchy, sailboat, analgesic, doubles, misinterpretation, justine,
# Nearest to heavy: metal, improvisation, naught, exuberance, ironworks, steaming, hedeby, praenomen,
# Nearest to quite: reason, actually, around, msh, explain, for, isolated, interrelated,
# Nearest to hold: same, participatory, content, attempting, mansfeld, dented, began, eternity,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7692 0.2138 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8266 0.2114 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8598 0.2107 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8245 0.2109 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8115 0.2100 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8884 0.2109 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8194 0.2107 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8043 0.2097 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8747 0.2106 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8595 0.2110 sec/batch
# Nearest to would: put, record, stationery, they, was, memnon, had, that,
# Nearest to system: telephones, cellular, ytv, systems, body, staffers, maha, soundex,
# Nearest to seven: eight, five, two, six, one, zero, three, four,
# Nearest to three: four, two, one, five, six, eight, zero, seven,
# Nearest to from: of, the, in, and, for, some, to, at,
# Nearest to some: such, most, are, from, non, the, also, and,
# Nearest to united: states, america, kingdom, new, makah, york, meanings, refer,
# Nearest to of: and, in, the, is, for, which, a, from,
# Nearest to ocean: pacific, intersputnik, hugely, incomes, atlantic, berkley, andaman, tropospheric,
# Nearest to frac: delta, mascheroni, t, approximates, fraca, therefore, left, indication,
# Nearest to square: photonic, werden, risc, often, houses, marshlands, stewie, genuinely,
# Nearest to freedom: constitutionalism, quartile, fuelling, gratis, recipients, speech, stilwell, englishman,
# Nearest to grand: usta, admirals, sailboat, analgesic, doubles, misinterpretation, duchy, justine,
# Nearest to heavy: improvisation, metal, naught, reactor, praenomen, exuberance, hedeby, ironworks,
# Nearest to quite: reason, actually, msh, around, explain, isolated, interrelated, datasets,
# Nearest to hold: same, participatory, content, attempting, began, representable, mansfeld, dented,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8839 0.2129 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8684 0.2107 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8413 0.2181 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8267 0.2500 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8710 0.2150 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8586 0.2225 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8127 0.2197 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8539 0.2097 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7957 0.2106 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7853 0.2104 sec/batch
# Nearest to would: put, record, only, that, memnon, they, was, not,
# Nearest to system: cellular, telephones, systems, body, ytv, maha, soundex, staffers,
# Nearest to seven: five, eight, two, three, one, six, zero, four,
# Nearest to three: four, two, one, five, six, eight, zero, seven,
# Nearest to from: of, the, in, and, some, by, for, to,
# Nearest to some: such, and, most, also, the, are, from, as,
# Nearest to united: states, america, kingdom, new, makah, meanings, nations, state,
# Nearest to of: and, in, the, a, for, is, which, from,
# Nearest to ocean: pacific, intersputnik, atlantic, hugely, berkley, incomes, andaman, consorts,
# Nearest to frac: mascheroni, delta, t, approximates, fraca, omega, permittivity, kilometer,
# Nearest to square: photonic, werden, marshlands, risc, often, houses, mosul, stewie,
# Nearest to freedom: speech, fuelling, quartile, constitutionalism, gratis, recipients, blessed, stilwell,
# Nearest to grand: usta, admirals, analgesic, sailboat, misinterpretation, doubles, duchy, justine,
# Nearest to heavy: metal, improvisation, exuberance, reactor, praenomen, naught, steaming, hedeby,
# Nearest to quite: reason, actually, msh, around, explain, can, isolated, for,
# Nearest to hold: participatory, same, content, attempting, began, mansfeld, sought, regard,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.9078 0.2133 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8302 0.2127 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9279 0.2117 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8986 0.2107 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8734 0.2103 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8429 0.2114 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7892 0.2094 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8168 0.2098 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7464 0.2103 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8566 0.2109 sec/batch
# Nearest to would: put, record, that, memnon, promised, only, they, stationery,
# Nearest to system: cellular, systems, telephones, ytv, body, staffers, soundex, maha,
# Nearest to seven: eight, five, two, six, one, three, zero, four,
# Nearest to three: two, four, six, five, one, eight, zero, seven,
# Nearest to from: of, the, in, for, by, and, some, to,
# Nearest to some: such, the, also, are, non, most, from, more,
# Nearest to united: states, america, makah, kingdom, new, york, meanings, state,
# Nearest to of: and, the, in, is, for, which, a, from,
# Nearest to ocean: pacific, intersputnik, atlantic, andaman, berkley, incomes, tropospheric, hugely,
# Nearest to frac: delta, mascheroni, approximates, t, fraca, therefore, omega, bentheim,
# Nearest to square: photonic, werden, marshlands, risc, stewie, houses, often, serpent,
# Nearest to freedom: quartile, speech, recipients, fuelling, constitutionalism, stilwell, gratis, blessed,
# Nearest to grand: usta, admirals, doubles, misinterpretation, sailboat, analgesic, justine, duchy,
# Nearest to heavy: improvisation, metal, exuberance, praenomen, reactor, hedeby, naught, steaming,
# Nearest to quite: reason, actually, msh, around, explain, interrelated, isolated, it,
# Nearest to hold: participatory, same, content, began, attempting, regard, acrylics, dented,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8497 0.2137 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8297 0.2142 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
